# %% [markdown]
# <a href="https://colab.research.google.com/github/Augustine25-git/Augustine/blob/main/CDAV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Body Temp Calculator

# %%
Temp=float(input('What is your body temperature? ')
)
print('Temp:',Temp*1.8+32)
# Out:
# What is your body temperature? 36.9
# Temp: 98.42

# %%
x=float(input('Enter the values: '))
y=float(input('Enter the values: '))
print('Sum:',x+y)
print('Subtract:',x-y)
print('multiply:',x*y)
print('Division:',x/y)
print('Modular:',x%y)
print('Fdivision:',x//y)
print('Square:',x**y)
# Out:
# Enter the values: 3.2
# Enter the values: 2.2
# Sum: 5.4
# Subtract: 1.0
# multiply: 7.040000000000001
# Division: 1.4545454545454546
# Modular: 1.0
# Fdivision: 1.0
# Square: 12.922006414954362

# %% [markdown]
# SPG

# %%
name=input('Enter name: ')
age=input('age: ')
currentCourse=input('Course: ')
print('name')
print('age')
print('currentCourse')
# Out:
# Enter name: Augustine
# age: 29
# Course: CDAV
# name
# age
# currentCourse

# %%
user=float(input('Body weight: '))
user=float(input('Body height: '))
bmi=Bodyweight/Bodyheight**Bodyheight
print('bmi')
# Out:
# Body weight: 57

# %% [markdown]
# Assigment

# %%
name = input("Enter student's name: ")
math = input("Enter Math score: ")
english = input("Enter English score: ")
science = input("Enter Science score: ")

# Convert test entries to numerical float types
math = float(math)
english = float(english)
science = float(science)

# Calculate the Total Score and the Grade Average
total = math + english + science
average = total / 3
print(average)
# Out:
# Enter student's name: Augustine
# Enter Math score: 94
# Enter English score: 90
# Enter Science score: 96
# 93.33333333333333

# %% [markdown]
# Python exercise

# %%
n=int(input('positive Int: '))
total= n*(n+1)/2
print(f'Sum of {n} is: {total}' )
# Out:
# positive Int: 6
# Sum of 6 is: 21.0

# %% [markdown]
# if statements

# %%
hungry= True
if hungry:
  print('Go EAT!')
# Out:
# Go EAT!

# %%
if not hungry:
  print("Dont go!")

# %% [markdown]
# BANK ATM

# %%
balance=500
withdrawalAmount=float(input('Enter amount to withdraw: '))
if withdrawalAmount>balance:
  print('Insufficient Funds')
if balance>=withdrawalAmount:
  print('Successful Withdrawal')
# Out:
# Enter amount to withdraw: 500
# Successful Withdrawal

# %% [markdown]
# Create a program to ask students for their exams marks if 50 or higher ,CELEBRATE success!!

# %%
exam=float(input('Exam grade: '))
if exam>=50:
  print('Congratulations!! VICTORY')
if exam<50:
  print('FAILED!')
# Out:
# Exam grade: 49
# FAILED!

# %% [markdown]
# if else

# %%
password=input('Enter Password: ')
if password == 'python123':
  print('ACCESS GRANTED')
else:
    print('ACCESS DENIED')
# Out:
# Enter Password: python123
# ACCESS GRANTED

# %% [markdown]
# ELIF

# %%
is_raining=input('RAINING type 1. if not type 2: ')
is_cloudy=input('RAINING type 1. if not type 2: ')
if is_raining=='1':
  print('use an umbrella')
elif is_cloudy == '1':
  print('carry an umbrella')
else:
  print('Dont carry umbrella')
# Out:
# RAINING type 1. if not type 2: 1
# RAINING type 1. if not type 2: 2
# use an umbrella

# %%
grade=input('Enter your grade: ')
if grade =='A':
  print('you scored above 80')
elif grade =='B':
  print('you scored between 71 and 80')
elif grade =='C':
  print('you scored between 61 and 70')
elif grade =='D':
  print('you scored between 51 and 60')
elif grade =='E':
  print('you scored between 41 and 50')
elif grade =='F':
  print('you scored below 41')
else:
  print('No Grading')
# Out:
# Enter your grade: B
# you scored between 71 and 80

# %% [markdown]
# AND && OR

# %% [markdown]
# Write a program that takes a value from the user the program should print divisible by 2 if the value is;
#
# *   divisible by 2
# *   divisible by 3 if the value is divisble by 3
# *   divisble by both 2 and 3
#
# * Other is should print not divisible by both 2 and 3

# %%
num=int(input('Enter number:'))
if num%2==0 & num%3==0:
  print('Both divisible by 2 and 3')

elif num%3==0:
  print('Divisble by 3')
elif num%2==0:
  print('Divisble by 2')
else:
  print('Not divisble')
# Out:
# Enter number:36
# Both divisible by 2 and 3
