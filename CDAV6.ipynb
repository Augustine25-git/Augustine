# %% [markdown]
# <a href="https://colab.research.google.com/github/Augustine25-git/CDAV/blob/main/CDAV6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Function

# %% [markdown]
# *   a block of reusable code
# *   They abstract/hide the actual code implementation

# %% [markdown]
# Types;
# Inbuilt: Functions that come in python already
# *   Call the function to use
# ---
# User-defined: Function created by you
#
# ---
# Function from packages/modules:
# *  Package- a set of reusable code consiting of functions,classes and variables
# *   Import-making a package available to your run time

# %%
import math

# %%
math.cbrt(1000)
# Out:
# 10.0

# %%
import numpy
numpy.__version__
# Out:
# '2.0.2'

# %%
from math import sqrt,cbrt as mt
sqrt(625)
# Out:
# 25.0

# %%
cbrt(625)
# Out:
# 8.549879733383484

# %% [markdown]
# User defined

# %%
import random
def greeter():
  greetings=['bonjour','jambo','hello','rada']
  print(greetings[random.randint(0,3)])

# %%
greeter()
# Out:
# rada

# %%
def add():
  return 10+20

# %%
add()+2
# Out:
# 32

# %%
import random
def greeter1():
  greetings=['bonjour','jambo','hello','rada']
  return greetings[random.randint(0,3)]

# %%
print(f'{greeter1()} Gusto')
# Out:
# rada Gusto

# %% [markdown]
# #Arguements
# -Variables inistialized within the brackets of a function definition and used within the function
# #Parameters
# -Values passed when calling the function between the brackets, they correspond to the arguements present when the function was created.

# %%
def greeter2(lang):
  print(lang)
  greetings={'fr':'bonjour',
             'sw':'jambo',
             'en':'hello',
             'sh':'rada'}
  return greetings[lang]

# %%
greeter2('fr')
# Out:
# fr
# 'bonjour'

# %%
mylang=input('Enter language you speak for a greeting: ')
greeter2(mylang)
# Out:
# Enter language you speak for a greeting: sh
# sh
# 'rada'

# %%
def authenticator(password):
  dpass ='seCret'
  if password == dpass:
    return True
  else:
    return False

# %%
passw=input('Enter a password: ')
if authenticator(passw):
  print('You are logged in')
else:
  print('Wrong Password Nga!!')
# Out:
# Enter a password: secret
# You are logged in

# %%
def sum_diff(x,y):
  s = x+y
  d=  x-y
  return(s,d)

# %%
sum_of_both,diff_of_both = sum_diff(100,50)
print(sum_of_both)
print(diff_of_both)
# Out:
# 150
# 50

# %%
def sum_of_two_three(a,b,c=0):
 return a+b+c

# %%
sum_of_two_three(8,3)
# Out:
# 11

# %%
day=int(input('Enter a birth day (1-31): '))
month=input('Enter a birth month: ')

if (month == 'December' and day >=22) or (month == 'January' and day <=19):
  print('Capricorn')
elif (month == 'January' and day >=20) or (month == 'February' and day <=18):
  print('Aquarius')
elif (month == 'February' and day >=19) or (month == 'March' and day <=20):
  print('Pisces')
elif (month == 'March' and day >=21) or (month == 'April' and day <=20):
  print('Aries')
elif (month == 'April' and day >=21) or (month == 'May' and day <=20):
  print('Taurus')
elif (month == 'May' and day >=21) or (month == 'June' and day <=20):
  print('Gemini')
elif (month == 'June' and day >=21) or (month == 'July' and day <=22):
  print('Cancer')
elif (month == 'July' and day >=23) or (month == 'August' and day <=22):
  print('Leo')
elif (month == 'August' and day >=23) or (month == 'September' and day <=22):
  print('Virgo')
elif (month == 'September' and day >=23) or (month == 'October' and day <=22):
  print('Libra')
elif (month == 'October' and day >=23) or (month == 'November' and day <=21):
  print('Scorpio')
elif (month == 'November' and day >=22) or (month == 'December' and day <=21):
  print('Sagittarius')
else:
  print('Wrong Input!!')
# Out:
# Enter a birth day (1-31): 25
# Enter a birth month: March
# Aries

# %%
year=int(input('Enter a animal year: '))


if year == 2000:
  print('Dragon')
elif year == 2001:
  print('Snake')
elif year == 2002 :
  print('Horse')
elif year == 2003:
  print('Sheep')
elif year == 2004:
  print('Monkey')
elif year == 2005:
  print('Rooster')
elif year == 2006:
  print('Dog')
elif year == 2007:
  print('Pig')
elif year == 2008:
  print('Rat')
elif year == 2009:
  print('Ox')
elif year == 2010:
  print('Tiger')
elif year == 2011:
  print('Hare')
else:
  print('Wrong Input')
# Out:
# Enter a animal year: 2006
# Dog

# %%
year=int(input('Enter a animal year: '))
if year % 12==8:
 print('Dragon')
elif year % 12==9:
 print('Snake')
elif year % 12==10:
 print('Horse')
elif year % 12==11:
 print('Sheep')
elif year % 12==0:
 print('Monkey')
elif year % 12==1:
 print('Rooster')
elif year % 12==2:
 print('Dog')
elif year % 12==3:
 print('Pig')
elif year % 12==4:
 print('Rat')
elif year % 12==5:
 print('Ox')
elif year % 12==6:
 print('Tiger')
elif year % 12==7:
 print('Hare')
else:
  print('Wrong Input')
# Out:
# Enter a animal year: 2006
# Dog

# %%
leapYear=int(input('Enter a year: '))
if leapYear % 4==0:
  print('Leap Year')
else:
  print('Not a Leap Year')
# Out:
# Enter a year: 2024
# Leap Year
