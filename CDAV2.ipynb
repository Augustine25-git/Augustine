# %% [markdown]
# <a href="https://colab.research.google.com/github/Augustine25-git/Augustine/blob/main/CDAV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 36: Vowel or Consonant

# %%
letter = input("Enter a letter of the alphabet: ")
if letter == "a" or letter == "e" or letter == "i" or letter =="o" or letter =="u":
  print("The letter entered is a vowel")
elif letter == ("y"):
  print("The letter entered is sometimes a vowel and sometimes a consonant")
else:
  print("The letter entered is a consonant")
# Out:
# Enter a letter of the alphabet: X
# The letter entered is a consonant

# %% [markdown]
#  39: Sound Levels

# %%
sound= int(input("Enter the sound level in decibels: "))
if sound > 130 :
  print("The sound level entered is louder than a Jackhammer.")
elif sound == 130:
  print("THis corresponds to a Jackhammer.")
elif sound > 106 and sound_level < 130:
  print("This is found between a Jackhammer and a Gas Lawnmower")
elif sound == 106:
  print("This correesponds to a Gas Lawnmower")
elif sound > 70 and sound_level < 106:
  print("This is found between an Alarm Clock and a Gas Lawnmower")
elif sound == 70:
  print("This corresponds to an Alarm Clock")
elif sound > 40 and sound_level < 70:
  print("This is found between a Quiet Room and an Alarm Clock")
elif sound == 40:
  print("This corresponds to a Quiet Room")
elif sound < 40:
  print("The sound level entered is quieter than a Quiet Room")
# Out:
# Enter the sound level in decibels: 70
# This corresponds to an Alarm Clock

# %% [markdown]
#  45: What Color is that Square?

# %%
letter =input("Enter a letter ")
if letter=="a" or letter=="c" or letter=="e" or letter=="g":
  letter=1
else:
  letter=2
num =input("Enter a number ")
if num=="1" or num=="3" or num=="5" or num=="7":
  number=1
else:
  number=2
report = (letter+number)

if report==2 or report==4:
  print("black")
else:
  print("white")
# Out:
# Enter a letter d
# Enter a number 1
# white
